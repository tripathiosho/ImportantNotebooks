# %% [markdown]
# <a href="https://colab.research.google.com/github/tripathiosho/ImportantNotebooks/blob/main/time_series_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
# !gdown 16TAoRZ3S8ebgIq3dPQmWIXPw_1dZy3ta
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=16TAoRZ3S8ebgIq3dPQmWIXPw_1dZy3ta
# To: /content/rest_vis.csv
# 100% 13.1k/13.1k [00:00<00:00, 27.7MB/s]

# %%
df = pd.read_csv('/content/rest_vis.csv')
df.head()
# Out:
#        date   weekday  holiday  total
# 0  1/1/2016    Friday        1  296.0
# 1  1/2/2016  Saturday        0  191.0
# 2  1/3/2016    Sunday        0  202.0
# 3  1/4/2016    Monday        0  105.0
# 4  1/5/2016   Tuesday        0   98.0

# %%
df['date'] = pd.to_datetime(df['date'])

# Set date as index
df = df.set_index('date').sort_index()

# %%
df.dropna(inplace = True)

# %%
df.head()
# Out:
#              weekday  holiday  total
# date
# 2016-01-01    Friday        1  296.0
# 2016-01-02  Saturday        0  191.0
# 2016-01-03    Sunday        0  202.0
# 2016-01-04    Monday        0  105.0
# 2016-01-05   Tuesday        0   98.0

# %%
weekend_days = {"Friday", "Saturday", "Sunday"}

df["is_weekend"] = df["weekday"].isin(weekend_days).astype(int)
df["is_weekday"] = (1 - df["is_weekend"]).astype(int)

# %%
df.head()
# Out:
#              weekday  holiday  total  is_weekend  is_weekday
# date
# 2016-01-01    Friday        1  296.0           1           0
# 2016-01-02  Saturday        0  191.0           1           0
# 2016-01-03    Sunday        0  202.0           1           0
# 2016-01-04    Monday        0  105.0           0           1
# 2016-01-05   Tuesday        0   98.0           0           1

# %%
exog = df[['is_weekend', 'is_weekday', 'holiday']]

# %%
train_x = df[['total']].iloc[:464]
test_x  = df[['total']].iloc[464:]

train_exog = exog.iloc[:464]
test_exog  = exog.iloc[464:]

# %%
train_x.plot()
# Out:
# <Axes: xlabel='date'>

# %%
from statsmodels.graphics.tsaplots import plot_pacf


# 2. Plot PACF
plt.figure(figsize=(8,4))
plot_pacf(train_x['total'], lags=28)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf


# 2. Plot PACF
plt.figure(figsize=(8,4))
plot_acf(train_x['total'], lags=28)
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model = SARIMAX(
    train_x['total'],
    exog=train_exog,
    order=(6,0,6),
    seasonal_order=(3,0,3,7)
)

results = model.fit(disp=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
forecast_1 = results.forecast(steps=len(test_x), exog=test_exog)

# %%
plt.plot(test_x,label='test_actual')
plt.plot(forecast_1, label='test_pred')
plt.legend()
plt.xticks(rotation=45)
# Out:
# (array([17265., 17267., 17269., 17271., 17273., 17275., 17277.]),
#  [Text(17265.0, 0, '2017-04-09'),
#   Text(17267.0, 0, '2017-04-11'),
#   Text(17269.0, 0, '2017-04-13'),
#   Text(17271.0, 0, '2017-04-15'),
#   Text(17273.0, 0, '2017-04-17'),
#   Text(17275.0, 0, '2017-04-19'),
#   Text(17277.0, 0, '2017-04-21')])

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape

mape(test_x, forecast_1)
# Out:
# 0.08519658027795136

# %% [markdown]
# # Using Linear Regression

# %%
df
# Out:
#               weekday  holiday  total  is_weekend  is_weekday
# date
# 2016-01-01     Friday        1  296.0           1           0
# 2016-01-02   Saturday        0  191.0           1           0
# 2016-01-03     Sunday        0  202.0           1           0
# 2016-01-04     Monday        0  105.0           0           1
# 2016-01-05    Tuesday        0   98.0           0           1
# ...               ...      ...    ...         ...         ...
# 2017-04-18    Tuesday        0   91.0           0           1
# 2017-04-19  Wednesday        0   79.0           0           1
# 2017-04-20   Thursday        0   90.0           0           1
# 2017-04-21     Friday        0  165.0           1           0
# 2017-04-22   Saturday        0  226.0           1           0
#
# [478 rows x 5 columns]

# %%
df['lag_1']  = df['total'].shift(1)
df['lag_2']  = df['total'].shift(2)
df['lag_3']  = df['total'].shift(3)
df['lag_4']  = df['total'].shift(4)
df['lag_5']  = df['total'].shift(5)
df['lag_6']  = df['total'].shift(6)
df['lag_7']  = df['total'].shift(7)
df['lag_14'] = df['total'].shift(14)

# %%
feature_cols = [
    'is_weekend',
    'is_weekday',
    'holiday',
    'lag_1',
    'lag_2',
    'lag_3',
    'lag_4',
    'lag_5',
    'lag_6',
    'lag_7',
    'lag_14'

]

df_model = df.dropna().copy()

# %%
df_model.head()
# Out:
#              weekday  holiday  total  is_weekend  is_weekday  lag_1  lag_2  \
# date
# 2016-01-15    Friday        0   95.0           1           0  106.0   65.0
# 2016-01-16  Saturday        0  237.0           1           0   95.0  106.0
# 2016-01-17    Sunday        0  197.0           1           0  237.0   95.0
# 2016-01-18    Monday        1  132.0           0           1  197.0  237.0
# 2016-01-19   Tuesday        0  100.0           0           1  132.0  197.0
#
#             lag_3  lag_4  lag_5  lag_6  lag_7  lag_14
# date
# 2016-01-15   57.0  101.0  212.0  234.0  149.0   296.0
# 2016-01-16   65.0   57.0  101.0  212.0  234.0   191.0
# 2016-01-17  106.0   65.0   57.0  101.0  212.0   202.0
# 2016-01-18   95.0  106.0   65.0   57.0  101.0   105.0
# 2016-01-19  237.0   95.0  106.0   65.0   57.0    98.0

# %%
X = df_model[feature_cols]
y = df_model['total']

# %%
df_model
# Out:
#               weekday  holiday  total  is_weekend  is_weekday  lag_1  lag_2  \
# date
# 2016-01-15     Friday        0   95.0           1           0  106.0   65.0
# 2016-01-16   Saturday        0  237.0           1           0   95.0  106.0
# 2016-01-17     Sunday        0  197.0           1           0  237.0   95.0
# 2016-01-18     Monday        1  132.0           0           1  197.0  237.0
# 2016-01-19    Tuesday        0  100.0           0           1  132.0  197.0
# ...               ...      ...    ...         ...         ...    ...    ...
# 2017-04-18    Tuesday        0   91.0           0           1  140.0  253.0
# 2017-04-19  Wednesday        0   79.0           0           1   91.0  140.0
# 2017-04-20   Thursday        0   90.0           0           1   79.0   91.0
# 2017-04-21     Friday        0  165.0           1           0   90.0   79.0
# 2017-04-22   Saturday        0  226.0           1           0  165.0   90.0
#
#             lag_3  lag_4  lag_5  lag_6  lag_7  lag_14
# date
# 2016-01-15   57.0  101.0  212.0  234.0  149.0   296.0
# 2016-01-16   65.0   57.0  101.0  212.0  234.0   191.0
# 2016-01-17  106.0   65.0   57.0  101.0  212.0   202.0
# 2016-01-18   95.0  106.0   65.0   57.0  101.0   105.0
# 2016-01-19  237.0   95.0  106.0   65.0   57.0    98.0
# ...           ...    ...    ...    ...    ...     ...
# 2017-04-18  218.0  221.0   70.0   89.0   77.0    99.0
# 2017-04-19  253.0  218.0  221.0   70.0   89.0    98.0
# 2017-04-20  140.0  253.0  218.0  221.0   70.0    74.0
# 2017-04-21   91.0  140.0  253.0  218.0  221.0   162.0
# 2017-04-22   79.0   91.0  140.0  253.0  218.0   191.0
#
# [464 rows x 13 columns]

# %%
split_idx = 450 # adjust index

X_train = X.iloc[:split_idx]
X_test  = X.iloc[split_idx:]

y_train = y.iloc[:split_idx]
y_test  = y.iloc[split_idx:]

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
plt.figure(figsize=(12,5))
plt.plot(y_test.index, y_test, label='Test')
plt.plot(y_test.index, y_pred, label='Predicted')

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape

mape(y_test, y_pred)
# Out:
# 0.09873508649580622

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor(
    n_estimators=200,
    learning_rate=0.06,
    max_depth=2,
    subsample=0.9,
    colsample_bytree=0.9,
    objective='reg:squarederror'
)

xgb.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.06, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=2,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_xgb = xgb.predict(X_test)
plt.figure(figsize=(12,5))

plt.plot(y_test.index, y_test, label='Test')
plt.plot(y_test.index, y_pred_xgb, label='XGBoost Forecast')

plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape

mape(y_test, y_pred_xgb)
# Out:
# 0.10597959319941422

# %% [markdown]
# # Prophet

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
df = pd.read_csv('/content/rest_vis.csv')
df.head()
# Out:
#        date   weekday  holiday  total
# 0  1/1/2016    Friday        1  296.0
# 1  1/2/2016  Saturday        0  191.0
# 2  1/3/2016    Sunday        0  202.0
# 3  1/4/2016    Monday        0  105.0
# 4  1/5/2016   Tuesday        0   98.0

# %%
df['date'] = pd.to_datetime(df['date'])

# Set date as index
df = df.set_index('date').sort_index()

# %%
df
# Out:
#               weekday  holiday  total
# date
# 2016-01-01     Friday        1  296.0
# 2016-01-02   Saturday        0  191.0
# 2016-01-03     Sunday        0  202.0
# 2016-01-04     Monday        0  105.0
# 2016-01-05    Tuesday        0   98.0
# ...               ...      ...    ...
# 2017-05-27   Saturday        0    NaN
# 2017-05-28     Sunday        0    NaN
# 2017-05-29     Monday        1    NaN
# 2017-05-30    Tuesday        0    NaN
# 2017-05-31  Wednesday        0    NaN
#
# [517 rows x 3 columns]

# %%
df.dropna(inplace = True)

# %%
weekend_days = {"Friday", "Saturday", "Sunday"}

df["is_weekend"] = df["weekday"].isin(weekend_days).astype(int)
df["is_weekday"] = (1 - df["is_weekend"]).astype(int)

# %%
df
# Out:
#               weekday  holiday  total  is_weekend  is_weekday
# date
# 2016-01-01     Friday        1  296.0           1           0
# 2016-01-02   Saturday        0  191.0           1           0
# 2016-01-03     Sunday        0  202.0           1           0
# 2016-01-04     Monday        0  105.0           0           1
# 2016-01-05    Tuesday        0   98.0           0           1
# ...               ...      ...    ...         ...         ...
# 2017-04-18    Tuesday        0   91.0           0           1
# 2017-04-19  Wednesday        0   79.0           0           1
# 2017-04-20   Thursday        0   90.0           0           1
# 2017-04-21     Friday        0  165.0           1           0
# 2017-04-22   Saturday        0  226.0           1           0
#
# [478 rows x 5 columns]

# %%
df_prophet = df.reset_index().rename(columns={
    'date': 'ds',
    'total': 'y'
})

# Select exogenous variable names
exog_cols = ['holiday', 'is_weekend', 'is_weekday']

# %%
df_prophet
# Out:
#             ds    weekday  holiday      y  is_weekend  is_weekday
# 0   2016-01-01     Friday        1  296.0           1           0
# 1   2016-01-02   Saturday        0  191.0           1           0
# 2   2016-01-03     Sunday        0  202.0           1           0
# 3   2016-01-04     Monday        0  105.0           0           1
# 4   2016-01-05    Tuesday        0   98.0           0           1
# ..         ...        ...      ...    ...         ...         ...
# 473 2017-04-18    Tuesday        0   91.0           0           1
# 474 2017-04-19  Wednesday        0   79.0           0           1
# 475 2017-04-20   Thursday        0   90.0           0           1
# 476 2017-04-21     Friday        0  165.0           1           0
# 477 2017-04-22   Saturday        0  226.0           1           0
#
# [478 rows x 6 columns]

# %%
train = df_prophet.iloc[:450].copy()
test  = df_prophet.iloc[450:].copy()

# %%
# !pip uninstall prophet pystan -y
# !pip install prophet
# !pip install cmdstanpy
# Out:
# Found existing installation: prophet 1.2.1
# Uninstalling prophet-1.2.1:
#   Successfully uninstalled prophet-1.2.1
# WARNING: Skipping pystan as it is not installed.
# Collecting prophet
#   Downloading prophet-1.2.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: cmdstanpy>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from prophet) (1.3.0)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.12/dist-packages (from prophet) (2.0.2)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from prophet) (3.10.0)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.12/dist-packages (from prophet) (2.2.2)
# Requirement already satisfied: holidays<1,>=0.25 in /usr/local/lib/python3.12/dist-packages (from prophet) (0.88)
# Requirement already satisfied: tqdm>=4.36.1 in /usr/local/lib/python3.12/dist-packages (from prophet) (4.67.1)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from prophet) (6.5.2)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from cmdstanpy>=1.0.4->prophet) (0.5.1)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->prophet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->prophet) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->prophet) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->prophet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->prophet) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->prophet) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=2.0.0->prophet) (3.3.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.4->prophet) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.4->prophet) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3,>=2.9.0.post0->holidays<1,>=0.25->prophet) (1.17.0)
# Downloading prophet-1.2.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 65.1 MB/s eta 0:00:00
# Installing collected packages: prophet
# Successfully installed prophet-1.2.1
# Requirement already satisfied: cmdstanpy in /usr/local/lib/python3.12/dist-packages (1.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from cmdstanpy) (2.2.2)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from cmdstanpy) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cmdstanpy) (4.67.1)
# Requirement already satisfied: stanio<2.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from cmdstanpy) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->cmdstanpy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->cmdstanpy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->cmdstanpy) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->cmdstanpy) (1.17.0)

# %%
from prophet import Prophet

#changepoint between 0 and 1
# seasonality_prior_scale - 0 to 20
# holidays_prior_scale - 0 to 20
m = Prophet(changepoint_prior_scale=0.8, seasonality_prior_scale=5,holidays_prior_scale=5)

# add regressors
for col in exog_cols:
    m.add_regressor(col)

m.add_seasonality(
    name='monthly',
    period=30.5,
    fourier_order=2
)

# fit
m.fit(train)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = test[['ds'] + exog_cols]
forecast = m.predict(future)

# %%
plt.figure(figsize=(12,5))
plt.plot(test['ds'], test['y'], label='Actual')
plt.plot(test['ds'], forecast['yhat'], label='Predicted')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape

mape(test['y'], forecast['yhat'])
# Out:
# 0.10320831897407838

# %%
df
# Out:
#               weekday  holiday  total  is_weekend  is_weekday
# date
# 2016-01-01     Friday        1  296.0           1           0
# 2016-01-02   Saturday        0  191.0           1           0
# 2016-01-03     Sunday        0  202.0           1           0
# 2016-01-04     Monday        0  105.0           0           1
# 2016-01-05    Tuesday        0   98.0           0           1
# ...               ...      ...    ...         ...         ...
# 2017-04-18    Tuesday        0   91.0           0           1
# 2017-04-19  Wednesday        0   79.0           0           1
# 2017-04-20   Thursday        0   90.0           0           1
# 2017-04-21     Friday        0  165.0           1           0
# 2017-04-22   Saturday        0  226.0           1           0
#
# [478 rows x 5 columns]

# %%
from prophet.plot import plot_components

fig = m.plot_components(forecast)

# %%
from prophet.plot import add_changepoints_to_plot
import matplotlib.pyplot as plt

train_future = train[['ds'] + exog_cols]
train_pred = m.predict(train_future)
fig = m.plot(train_pred)
_ = add_changepoints_to_plot(fig.gca(), m, train_pred)

# %%
a
