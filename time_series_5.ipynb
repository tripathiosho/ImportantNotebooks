# %% [markdown]
# <a href="https://colab.research.google.com/github/tripathiosho/ImportantNotebooks/blob/main/time_series_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
mobile_sales = pd.read_csv('/content/drive/MyDrive/Time Series and Recsys data/time_series_2_data.csv')

# %%
mobile_sales = mobile_sales.set_index('DATE')

# %%
mobile_sales.index = pd.to_datetime(mobile_sales.index)

# %%
mobile_sales = mobile_sales.asfreq('MS')

# %%
train_x = mobile_sales.iloc[:193]
test_x = mobile_sales.iloc[193:]

# %%
from statsmodels.graphics.tsaplots import plot_pacf
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 4))

# Plot PACF
plot_pacf(train_x['Sales'], lags=48, ax=ax)

# Mark seasonal lags
seasonal_lags = [12, 24, 36]

for lag in seasonal_lags:
    ax.axvline(lag, linestyle='--', linewidth=1)

plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(8, 4))

# Plot PACF
plot_acf(train_x['Sales'], lags=48, ax=ax)

# Mark seasonal lags
seasonal_lags = [12, 24, 36]

for lag in seasonal_lags:
    ax.axvline(lag, linestyle='--', linewidth=1)

plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model = SARIMAX(train_x.Sales, order=(5, 1, 1),seasonal_order=(2,0,2,12))
model = model.fit(disp=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
forecast_1 = model.forecast(steps=24)

# %%
plt.plot(test_x,label='test_actual')
plt.plot(forecast_1, label='test_pred')

# %%
model = SARIMAX(train_x.Sales, order=(5,1,1), seasonal_order=(2,0,2,12))
model_fit = model.fit(disp=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
forecast_res = model_fit.get_forecast(steps=100)
forecast_mean = forecast_res.predicted_mean
forecast_ci = forecast_res.conf_int(alpha=0.05)

# %%
forecast_ci
# Out:
#              lower Sales   upper Sales
# 2017-02-01   9970.719767  14299.105898
# 2017-03-01  11125.932739  15511.454923
# 2017-04-01  10990.310772  15507.603911
# 2017-05-01  11611.763768  16285.963829
# 2017-06-01  12313.261027  17091.605429
# ...                  ...           ...
# 2025-01-01   9204.015176  17984.950892
# 2025-02-01   9948.274075  18894.425981
# 2025-03-01  10897.290975  19881.758823
# 2025-04-01  10867.489190  19898.186947
# 2025-05-01  11376.708521  20455.647899
#
# [100 rows x 2 columns]

# %%
plt.figure(figsize=(10,5))

# 1. Plot test data ONLY IF it aligns with forecast index
plt.plot(test_x.index, test_x.Sales, label='Actual Test')

# 2. Plot forecast (future)
plt.plot(forecast_mean.index, forecast_mean, label='Forecast')

# 3. Plot forecast confidence intervals (will widen)
plt.fill_between(
    forecast_ci.index,
    forecast_ci.iloc[:, 0],
    forecast_ci.iloc[:, 1],
    alpha=0.3,
    label='95% CI'
)

plt.legend()
plt.show()

# %% [markdown]
# # Change point

# %%
mobile_sales
# Out:
#                Sales
# DATE
# 2001-01-01   6802.44
# 2001-02-01   6802.44
# 2001-03-01   7332.00
# 2001-04-01   7332.00
# 2001-05-01   8240.00
# ...              ...
# 2018-09-01  13838.00
# 2018-10-01  15351.00
# 2018-11-01  15615.00
# 2018-12-01  15809.40
# 2019-01-01  12160.00
#
# [217 rows x 1 columns]

# %%
pip install ruptures
# Out:
# Collecting ruptures
#   Downloading ruptures-1.1.10-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from ruptures) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from ruptures) (1.16.3)
# Downloading ruptures-1.1.10-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.1 MB/s eta 0:00:00
# Installing collected packages: ruptures
# Successfully installed ruptures-1.1.10

# %%
import ruptures as rpt
import matplotlib.pyplot as plt

# l2 - linear , rbf - non linear
model = rpt.Pelt(model="rbf").fit(mobile_sales)

change_points = model.predict(pen=1)

print("Detected change points (indices):", change_points)
# Out:
# Detected change points (indices): [30, 65, 110, 135, 185, 217]

# %%
plt.figure(figsize=(12,6))
plt.plot(mobile_sales.index,mobile_sales, label="Mobile Sales")

# Draw vertical lines for detected change points
for cp in change_points[:-1]:  # last point is length of series
    plt.axvline(x=mobile_sales.index[cp], color='red', linestyle='--', label='Change Point')


plt.title("Mobile Sales with Detected Change Points (ruptures)")
plt.show()

# %%
# !gdown 16TAoRZ3S8ebgIq3dPQmWIXPw_1dZy3ta
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=16TAoRZ3S8ebgIq3dPQmWIXPw_1dZy3ta
# To: /content/rest_vis.csv
# 100% 13.1k/13.1k [00:00<00:00, 38.2MB/s]

# %%
df = pd.read_csv('/content/rest_vis.csv')
df.head()
# Out:
#        date   weekday  holiday  total
# 0  1/1/2016    Friday        1  296.0
# 1  1/2/2016  Saturday        0  191.0
# 2  1/3/2016    Sunday        0  202.0
# 3  1/4/2016    Monday        0  105.0
# 4  1/5/2016   Tuesday        0   98.0

# %%
df.head(15)
# Out:
#          date    weekday  holiday  total
# 0    1/1/2016     Friday        1  296.0
# 1    1/2/2016   Saturday        0  191.0
# 2    1/3/2016     Sunday        0  202.0
# 3    1/4/2016     Monday        0  105.0
# 4    1/5/2016    Tuesday        0   98.0
# 5    1/6/2016  Wednesday        0   83.0
# 6    1/7/2016   Thursday        0   69.0
# 7    1/8/2016     Friday        0  149.0
# 8    1/9/2016   Saturday        0  234.0
# 9   1/10/2016     Sunday        0  212.0
# 10  1/11/2016     Monday        0  101.0
# 11  1/12/2016    Tuesday        0   57.0
# 12  1/13/2016  Wednesday        0   65.0
# 13  1/14/2016   Thursday        0  106.0
# 14  1/15/2016     Friday        0   95.0

# %%
df
# Out:
#               weekday  holiday  total
# date
# 2016-01-01     Friday        1  296.0
# 2016-01-02   Saturday        0  191.0
# 2016-01-03     Sunday        0  202.0
# 2016-01-04     Monday        0  105.0
# 2016-01-05    Tuesday        0   98.0
# ...               ...      ...    ...
# 2017-05-27   Saturday        0    NaN
# 2017-05-28     Sunday        0    NaN
# 2017-05-29     Monday        1    NaN
# 2017-05-30    Tuesday        0    NaN
# 2017-05-31  Wednesday        0    NaN
#
# [517 rows x 3 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# Set date as index
df = df.set_index('date').sort_index()

# %%
(df.index[-1] - df.index[0]).days + 1
# Out:
# 517

# %%
len(df)
# Out:
# 517

# %%
df.isna().sum()
# Out:
# weekday     0
# holiday     0
# total      39
# dtype: int64

# %%
df
# Out:
#               weekday  holiday  total
# date
# 2016-01-01     Friday        1  296.0
# 2016-01-02   Saturday        0  191.0
# 2016-01-03     Sunday        0  202.0
# 2016-01-04     Monday        0  105.0
# 2016-01-05    Tuesday        0   98.0
# ...               ...      ...    ...
# 2017-05-27   Saturday        0    NaN
# 2017-05-28     Sunday        0    NaN
# 2017-05-29     Monday        1    NaN
# 2017-05-30    Tuesday        0    NaN
# 2017-05-31  Wednesday        0    NaN
#
# [517 rows x 3 columns]

# %%
df.tail(39).isna().sum()
# Out:
# weekday     0
# holiday     0
# total      39
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#               weekday  holiday  total
# date
# 2016-01-01     Friday        1  296.0
# 2016-01-02   Saturday        0  191.0
# 2016-01-03     Sunday        0  202.0
# 2016-01-04     Monday        0  105.0
# 2016-01-05    Tuesday        0   98.0
# ...               ...      ...    ...
# 2017-04-18    Tuesday        0   91.0
# 2017-04-19  Wednesday        0   79.0
# 2017-04-20   Thursday        0   90.0
# 2017-04-21     Friday        0  165.0
# 2017-04-22   Saturday        0  226.0
#
# [478 rows x 3 columns]

# %%
df['total'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
import statsmodels.api as sm
sm.tsa.seasonal_decompose(df.total,model='additive').plot();

# %%
train_x = df[['total']].iloc[:464]
test_x = df[['total']].iloc[464:]

# %%
test_x
# Out:
#             total
# date
# 2017-04-09  177.0
# 2017-04-10   73.0
# 2017-04-11   77.0
# 2017-04-12   89.0
# 2017-04-13   70.0
# 2017-04-14  221.0
# 2017-04-15  218.0
# 2017-04-16  253.0
# 2017-04-17  140.0
# 2017-04-18   91.0
# 2017-04-19   79.0
# 2017-04-20   90.0
# 2017-04-21  165.0
# 2017-04-22  226.0

# %%
def adf_test(dataset):
   pvalue = sm.tsa.stattools.adfuller(dataset)[1]
   if pvalue <= 0.05:
      print('Sequence is stationary')
   else:
      print('Sequence is not stationary')

adf_test(train_x.total)
# Out:
# Sequence is stationary

# %%
train_x[20:40].plot()
# Out:
# <Axes: xlabel='date'>

# %%
from statsmodels.graphics.tsaplots import plot_pacf


# 2. Plot PACF
plt.figure(figsize=(8,4))
plot_pacf(train_x['total'], lags=20)
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf


# 2. Plot PACF
plt.figure(figsize=(8,4))
plot_acf(train_x['total'], lags=20)
plt.show()

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

model = SARIMAX(train_x.total, order=(6, 0, 6),seasonal_order=(2,0,3,7))
model = model.fit(disp=False)

# Step 3: Optional - one-step forecast
forecast_1 = model.forecast(steps=14)
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.12/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
plt.plot(test_x,label='test_actual')
plt.plot(forecast_1, label='test_pred')
plt.legend()
plt.xticks(rotation=45)
# Out:
# (array([17265., 17267., 17269., 17271., 17273., 17275., 17277.]),
#  [Text(17265.0, 0, '2017-04-09'),
#   Text(17267.0, 0, '2017-04-11'),
#   Text(17269.0, 0, '2017-04-13'),
#   Text(17271.0, 0, '2017-04-15'),
#   Text(17273.0, 0, '2017-04-17'),
#   Text(17275.0, 0, '2017-04-19'),
#   Text(17277.0, 0, '2017-04-21')])

# %%
from sklearn.metrics import mean_absolute_percentage_error as mape

mape(test_x, forecast_1)
# Out:
# 0.16791166839908808

# %%
model.plot_diagnostics(figsize=(8,8));

# %%
test_x['forecast'] = forecast_1

# %%
test_x
# Out:
#             total    forecast
# date
# 2017-04-09  177.0  167.101398
# 2017-04-10   73.0   88.257712
# 2017-04-11   77.0   94.233951
# 2017-04-12   89.0   91.740134
# 2017-04-13   70.0   93.533393
# 2017-04-14  221.0  141.872864
# 2017-04-15  218.0  228.708135
# 2017-04-16  253.0  175.284545
# 2017-04-17  140.0   87.512776
# 2017-04-18   91.0   91.161105
# 2017-04-19   79.0   94.646679
# 2017-04-20   90.0   97.173998
# 2017-04-21  165.0  145.199636
# 2017-04-22  226.0  227.411101

# %%
df
# Out:
#               weekday  holiday  total
# date
# 2016-01-01     Friday        1  296.0
# 2016-01-02   Saturday        0  191.0
# 2016-01-03     Sunday        0  202.0
# 2016-01-04     Monday        0  105.0
# 2016-01-05    Tuesday        0   98.0
# ...               ...      ...    ...
# 2017-04-18    Tuesday        0   91.0
# 2017-04-19  Wednesday        0   79.0
# 2017-04-20   Thursday        0   90.0
# 2017-04-21     Friday        0  165.0
# 2017-04-22   Saturday        0  226.0
#
# [478 rows x 3 columns]
